# %% [markdown]
# # Turtle Trading Optimisation
#
# In this notebook, I optimize the parameters for the Turtle Trading strategy. Optimization may lead to overfitting of the strategy to historical data, but it is still good to observe the effects of various parameters on the performance of the strategy.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
from utils import misc
import datetime as dt
from trade_obj import *
from simple_backtester import backTester
from mpl_toolkits.mplot3d import Axes3D
import optuna



ticker = 'SPY'
df = pd.read_csv('datasets/stock_price_series/' + ticker + '.csv')
df = misc.clean_df(df)
df = df.set_index('date')

# %% [markdown]
# Generate indicators for entry and exit

# %%
def generate_high_low(df, high_window, low_window):

    df['up_bound'] = df['high'].shift(1).rolling(high_window).max()
    df['low_bound'] = df['low'].shift(1).rolling(low_window).min()

    return df

def generate_atr(df, window):
    df['High-Low'] = df['high'] - df['low']
    df['High-PrevClose'] = abs(df['high'] - df['close'].shift(1))
    df['Low-PrevClose'] = abs(df['low'] - df['close'].shift(1))
    df['TR'] = df[['High-Low', 'High-PrevClose', 'Low-PrevClose']].max(axis=1)
    df['ATR'] = df['TR'].rolling(window).mean()

    return df

def generate_sma(df, long_window, short_window):
    df['long_sma'] = df['close'].rolling(long_window).mean().shift(2)
    df['short_sma'] = df['close'].rolling(short_window).mean().shift(2)

    return df

# %% [markdown]
# ### High-Low Window with trailing stop loss

# %%
def hatr_backtest(df, high_window, low_window, atr_window, atr_multiple):

    df = generate_high_low(df, high_window=high_window, low_window=low_window)
    df = generate_atr(df, atr_window)
    df['ATR'] = df['ATR'].shift(1)
    atr = df['ATR'].to_numpy()

    df.dropna(inplace=True)

    df['signal'] = 0

    # Generate trading signals
    df.loc[df['high'].shift(1) > df['up_bound'].shift(2), 'signal'] = 1    

    trades_arr = df['signal'].to_numpy()

    bt = backTester()
    bt.set_asset(df)

    tl = tradeList()

    open_trade = None
    stop_loss = np.nan
    stop_arr = []
    

    for i in range(len(bt.df)):
        
        order_quantity = 0
        order_price = 0
        

        if trades_arr[i] == 1 and open_trade == None:
    
            # order price at breakout
            order_price = bt.open[i]
            # order 1 unit
            order_quantity = bt.cash // order_price
            # open trade on record
            open_trade = trade(bt.date[i], order_price, order_quantity)
            n3 = atr_multiple * atr[i]
            stop_loss = order_price - n3
            
        # open trades present 
        elif open_trade != None:
            stop_loss = max(stop_loss, bt.high[i] - n3, df['low_bound'][i])
            if bt.low[i] < stop_loss:

                order_price = stop_loss
                order_quantity = -open_trade.quantity
                    
                open_trade.close(bt.date[i], order_price)
                tl.append(open_trade)
                
                open_trade = None
                stop_loss = np.nan
        
        stop_arr.append(stop_loss)

        bt.take_action(order_quantity=order_quantity, order_price=order_price)
    bt.df['stop_loss'] = stop_arr

    return bt, tl

# %%
def objective(trial):
    # Define the parameters to optimize
    h_wind = trial.suggest_int('high_window', 5, 200)
    l_wind = trial.suggest_int('low_window', 5, 200)
    atr_wind = trial.suggest_int('atr_window', 5, 100)
    atr_mult = trial.suggest_int('atr_multiple', 1, 10)
    
    # Call your function with the chosen parameters
    bt, _ = hatr_backtest(
            df.copy(), 
            high_window=h_wind, 
            low_window=l_wind, 
            atr_window=atr_wind, 
            atr_multiple=atr_mult
            )
    
    bt.analyse()
    # Define the objective to minimize or maximize (e.g., error or loss)
    objective_value = bt.sharpe  # Assuming you want to maximize the result
    
    return objective_value

# Create an Optuna study
study = optuna.create_study(direction='maximize')

# Run the optimization process
study.optimize(objective, n_trials=200)

# Get the best parameters and objective value
best_params = study.best_params
best_value = study.best_value

print("Best Parameters:", best_params)
print("Best Value:", best_value)
# Out:
# [I 2023-07-11 15:05:31,204] A new study created in memory with name: no-name-2b6cabdb-5473-41cc-924b-f5352d0a32d0
# [I 2023-07-11 15:05:31,351] Trial 0 finished with value: 0.6055669311778645 and parameters: {'high_window': 37, 'low_window': 195, 'atr_window': 92, 'atr_multiple': 9}. Best is trial 0 with value: 0.6055669311778645.
# [I 2023-07-11 15:05:31,452] Trial 1 finished with value: 0.6090405115902974 and parameters: {'high_window': 76, 'low_window': 105, 'atr_window': 57, 'atr_multiple': 5}. Best is trial 1 with value: 0.6090405115902974.
# [I 2023-07-11 15:05:31,552] Trial 2 finished with value: 0.6040252467929206 and parameters: {'high_window': 89, 'low_window': 154, 'atr_window': 82, 'atr_multiple': 2}. Best is trial 1 with value: 0.6090405115902974.
# [I 2023-07-11 15:05:31,650] Trial 3 finished with value: 0.6081334407541501 and parameters: {'high_window': 140, 'low_window': 137, 'atr_window': 80, 'atr_multiple': 7}. Best is trial 1 with value: 0.6090405115902974.
# [I 2023-07-11 15:05:31,749] Trial 4 finished with value: 0.6040700347125821 and parameters: {'high_window': 95, 'low_window': 155, 'atr_window': 56, 'atr_multiple': 1}. Best is trial 1 with value: 0.6090405115902974.
# [I 2023-07-11 15:05:31,844] Trial 5 finished with value: 0.5986504045316411 and parameters: {'high_window': 191, 'low_window': 195, 'atr_window': 13, 'atr_multiple': 6}. Best is trial 1 with value: 0.6090405115902974.
# [I 2023-07-11 15:05:31,945] Trial 6 finished with value: 0.6127020807227698 and parameters: {'high_window': 24, 'low_window': 100, 'atr_window': 68, 'atr_multiple': 7}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:32,047] Trial 7 finished with value: 0.6051028988484379 and parameters: {'high_window': 178, 'low_window': 162, 'atr_window': 95, 'atr_multiple': 4}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:32,147] Trial 8 finished with value: 0.6050578821218828 and parameters: {'high_window': 78, 'low_window': 177, 'atr_window': 33, 'atr_multiple': 2}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:32,248] Trial 9 finished with value: 0.6080884147502273 and parameters: {'high_window': 139, 'low_window': 101, 'atr_window': 26, 'atr_multiple': 9}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:32,367] Trial 10 finished with value: 0.6117887771112674 and parameters: {'high_window': 9, 'low_window': 22, 'atr_window': 69, 'atr_multiple': 10}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:32,533] Trial 11 finished with value: 0.6117438947276079 and parameters: {'high_window': 6, 'low_window': 8, 'atr_window': 68, 'atr_multiple': 10}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:32,652] Trial 12 finished with value: 0.6086549177840858 and parameters: {'high_window': 6, 'low_window': 7, 'atr_window': 41, 'atr_multiple': 8}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:32,775] Trial 13 finished with value: 0.6079506461172095 and parameters: {'high_window': 44, 'low_window': 49, 'atr_window': 69, 'atr_multiple': 10}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:32,897] Trial 14 finished with value: 0.6080398210658291 and parameters: {'high_window': 41, 'low_window': 54, 'atr_window': 71, 'atr_multiple': 7}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:33,019] Trial 15 finished with value: 0.6101345693536901 and parameters: {'high_window': 25, 'low_window': 54, 'atr_window': 46, 'atr_multiple': 4}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:33,139] Trial 16 finished with value: 0.6085473651431358 and parameters: {'high_window': 60, 'low_window': 94, 'atr_window': 59, 'atr_multiple': 8}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:33,303] Trial 17 finished with value: 0.6093933208161121 and parameters: {'high_window': 21, 'low_window': 73, 'atr_window': 83, 'atr_multiple': 8}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:33,417] Trial 18 finished with value: 0.3758756938887209 and parameters: {'high_window': 60, 'low_window': 34, 'atr_window': 65, 'atr_multiple': 6}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:33,548] Trial 19 finished with value: 0.6097149090957219 and parameters: {'high_window': 117, 'low_window': 120, 'atr_window': 46, 'atr_multiple': 10}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:33,682] Trial 20 finished with value: 0.6094898624917869 and parameters: {'high_window': 115, 'low_window': 73, 'atr_window': 77, 'atr_multiple': 5}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:33,806] Trial 21 finished with value: 0.6116541594163749 and parameters: {'high_window': 5, 'low_window': 7, 'atr_window': 66, 'atr_multiple': 10}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:33,969] Trial 22 finished with value: 0.6121609832938784 and parameters: {'high_window': 19, 'low_window': 23, 'atr_window': 88, 'atr_multiple': 9}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:34,108] Trial 23 finished with value: 0.6121609832938784 and parameters: {'high_window': 28, 'low_window': 29, 'atr_window': 88, 'atr_multiple': 9}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:34,276] Trial 24 finished with value: 0.6088162063911199 and parameters: {'high_window': 55, 'low_window': 33, 'atr_window': 100, 'atr_multiple': 7}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:34,398] Trial 25 finished with value: 0.6122060203160438 and parameters: {'high_window': 27, 'low_window': 75, 'atr_window': 89, 'atr_multiple': 9}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:34,522] Trial 26 finished with value: 0.6090086645432362 and parameters: {'high_window': 50, 'low_window': 80, 'atr_window': 87, 'atr_multiple': 8}. Best is trial 6 with value: 0.6127020807227698.
# [I 2023-07-11 15:05:34,645] Trial 27 finished with value: 0.6137431839330272 and parameters: {'high_window': 24, 'low_window': 123, 'atr_window': 99, 'atr_multiple': 9}. Best is trial 27 with value: 0.6137431839330272.
# [I 2023-07-11 15:05:34,768] Trial 28 finished with value: 0.6097599481666216 and parameters: {'high_window': 69, 'low_window': 121, 'atr_window': 100, 'atr_multiple': 7}. Best is trial 27 with value: 0.6137431839330272.
# [I 2023-07-11 15:05:34,888] Trial 29 finished with value: 0.6136070885779238 and parameters: {'high_window': 36, 'low_window': 120, 'atr_window': 94, 'atr_multiple': 9}. Best is trial 27 with value: 0.6137431839330272.
# [I 2023-07-11 15:05:35,011] Trial 30 finished with value: 0.6140610902043551 and parameters: {'high_window': 37, 'low_window': 130, 'atr_window': 95, 'atr_multiple': 8}. Best is trial 30 with value: 0.6140610902043551.
# [I 2023-07-11 15:05:35,135] Trial 31 finished with value: 0.614106545490334 and parameters: {'high_window': 30, 'low_window': 131, 'atr_window': 95, 'atr_multiple': 8}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:35,257] Trial 32 finished with value: 0.614015644951806 and parameters: {'high_window': 36, 'low_window': 129, 'atr_window': 93, 'atr_multiple': 8}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:35,379] Trial 33 finished with value: 0.6133121273132554 and parameters: {'high_window': 37, 'low_window': 135, 'atr_window': 96, 'atr_multiple': 8}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:35,495] Trial 34 finished with value: 0.6103915389541672 and parameters: {'high_window': 72, 'low_window': 135, 'atr_window': 76, 'atr_multiple': 6}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:35,621] Trial 35 finished with value: 0.6078834971642164 and parameters: {'high_window': 87, 'low_window': 143, 'atr_window': 82, 'atr_multiple': 8}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:35,746] Trial 36 finished with value: 0.6123152887563689 and parameters: {'high_window': 45, 'low_window': 113, 'atr_window': 94, 'atr_multiple': 7}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:35,914] Trial 37 finished with value: 0.6045184594491604 and parameters: {'high_window': 17, 'low_window': 165, 'atr_window': 98, 'atr_multiple': 5}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:36,034] Trial 38 finished with value: 0.6072090653496937 and parameters: {'high_window': 33, 'low_window': 145, 'atr_window': 91, 'atr_multiple': 8}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:36,148] Trial 39 finished with value: 0.5436710087506604 and parameters: {'high_window': 62, 'low_window': 129, 'atr_window': 5, 'atr_multiple': 9}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:36,272] Trial 40 finished with value: 0.6050578821218828 and parameters: {'high_window': 169, 'low_window': 177, 'atr_window': 75, 'atr_multiple': 6}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:36,396] Trial 41 finished with value: 0.6131540866323848 and parameters: {'high_window': 36, 'low_window': 110, 'atr_window': 94, 'atr_multiple': 9}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:36,519] Trial 42 finished with value: 0.6138339642024915 and parameters: {'high_window': 16, 'low_window': 125, 'atr_window': 84, 'atr_multiple': 9}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:36,646] Trial 43 finished with value: 0.6128200451648651 and parameters: {'high_window': 15, 'low_window': 90, 'atr_window': 84, 'atr_multiple': 9}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:36,768] Trial 44 finished with value: 0.6038909424455497 and parameters: {'high_window': 50, 'low_window': 151, 'atr_window': 91, 'atr_multiple': 7}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:36,895] Trial 45 finished with value: 0.6139247845323104 and parameters: {'high_window': 14, 'low_window': 127, 'atr_window': 79, 'atr_multiple': 10}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:37,017] Trial 46 finished with value: 0.604249285507499 and parameters: {'high_window': 14, 'low_window': 159, 'atr_window': 80, 'atr_multiple': 10}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:37,139] Trial 47 finished with value: 0.6046531806205359 and parameters: {'high_window': 30, 'low_window': 168, 'atr_window': 85, 'atr_multiple': 2}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:37,265] Trial 48 finished with value: 0.6089956308301052 and parameters: {'high_window': 80, 'low_window': 104, 'atr_window': 73, 'atr_multiple': 10}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:37,390] Trial 49 finished with value: 0.6072540574603917 and parameters: {'high_window': 13, 'low_window': 146, 'atr_window': 79, 'atr_multiple': 1}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:37,559] Trial 50 finished with value: 0.610165746872645 and parameters: {'high_window': 99, 'low_window': 130, 'atr_window': 62, 'atr_multiple': 4}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:37,705] Trial 51 finished with value: 0.6129490807799971 and parameters: {'high_window': 46, 'low_window': 127, 'atr_window': 98, 'atr_multiple': 8}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:37,847] Trial 52 finished with value: 0.6131540866323848 and parameters: {'high_window': 23, 'low_window': 110, 'atr_window': 92, 'atr_multiple': 9}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:37,970] Trial 53 finished with value: 0.6140413108747453 and parameters: {'high_window': 11, 'low_window': 117, 'atr_window': 96, 'atr_multiple': 10}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:38,103] Trial 54 finished with value: 0.608178476704161 and parameters: {'high_window': 5, 'low_window': 141, 'atr_window': 86, 'atr_multiple': 10}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:38,237] Trial 55 finished with value: 0.6138599244933451 and parameters: {'high_window': 13, 'low_window': 113, 'atr_window': 30, 'atr_multiple': 10}. Best is trial 31 with value: 0.614106545490334.
# [I 2023-07-11 15:05:38,366] Trial 56 finished with value: 0.6743835636437836 and parameters: {'high_window': 41, 'low_window': 94, 'atr_window': 19, 'atr_multiple': 10}. Best is trial 56 with value: 0.6743835636437836.
# [I 2023-07-11 15:05:38,493] Trial 57 finished with value: 0.6685432131930804 and parameters: {'high_window': 39, 'low_window': 91, 'atr_window': 20, 'atr_multiple': 10}. Best is trial 56 with value: 0.6743835636437836.
# [I 2023-07-11 15:05:38,617] Trial 58 finished with value: 0.6452088340380127 and parameters: {'high_window': 41, 'low_window': 91, 'atr_window': 20, 'atr_multiple': 10}. Best is trial 56 with value: 0.6743835636437836.
# [I 2023-07-11 15:05:38,734] Trial 59 finished with value: 0.4158414921718872 and parameters: {'high_window': 64, 'low_window': 91, 'atr_window': 18, 'atr_multiple': 10}. Best is trial 56 with value: 0.6743835636437836.
# [I 2023-07-11 15:05:38,872] Trial 60 finished with value: 0.6100538707983176 and parameters: {'high_window': 41, 'low_window': 81, 'atr_window': 16, 'atr_multiple': 10}. Best is trial 56 with value: 0.6743835636437836.
# [I 2023-07-11 15:05:39,001] Trial 61 finished with value: 0.6555072236902402 and parameters: {'high_window': 54, 'low_window': 102, 'atr_window': 27, 'atr_multiple': 3}. Best is trial 56 with value: 0.6743835636437836.
# [I 2023-07-11 15:05:39,145] Trial 62 finished with value: 0.6086780909747381 and parameters: {'high_window': 53, 'low_window': 67, 'atr_window': 22, 'atr_multiple': 3}. Best is trial 56 with value: 0.6743835636437836.
# [I 2023-07-11 15:05:39,310] Trial 63 finished with value: 0.48858837806105626 and parameters: {'high_window': 30, 'low_window': 93, 'atr_window': 37, 'atr_multiple': 10}. Best is trial 56 with value: 0.6743835636437836.
# [I 2023-07-11 15:05:39,414] Trial 64 finished with value: 0.4523872242353316 and parameters: {'high_window': 44, 'low_window': 97, 'atr_window': 10, 'atr_multiple': 2}. Best is trial 56 with value: 0.6743835636437836.
# [I 2023-07-11 15:05:39,519] Trial 65 finished with value: 0.7851047779701882 and parameters: {'high_window': 108, 'low_window': 87, 'atr_window': 28, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:39,628] Trial 66 finished with value: 0.47826713150988576 and parameters: {'high_window': 91, 'low_window': 64, 'atr_window': 27, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:39,763] Trial 67 finished with value: 0.6099402037381115 and parameters: {'high_window': 125, 'low_window': 81, 'atr_window': 22, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:39,869] Trial 68 finished with value: 0.6286352837865431 and parameters: {'high_window': 106, 'low_window': 87, 'atr_window': 33, 'atr_multiple': 4}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:39,997] Trial 69 finished with value: 0.6092650634737742 and parameters: {'high_window': 110, 'low_window': 86, 'atr_window': 33, 'atr_multiple': 4}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:40,124] Trial 70 finished with value: 0.6088162063911199 and parameters: {'high_window': 100, 'low_window': 100, 'atr_window': 50, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:40,250] Trial 71 finished with value: 0.6097599481666216 and parameters: {'high_window': 121, 'low_window': 106, 'atr_window': 21, 'atr_multiple': 4}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:40,376] Trial 72 finished with value: 0.6103463606002323 and parameters: {'high_window': 134, 'low_window': 86, 'atr_window': 25, 'atr_multiple': 5}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:40,485] Trial 73 finished with value: 0.61860019492122 and parameters: {'high_window': 108, 'low_window': 63, 'atr_window': 11, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:40,595] Trial 74 finished with value: 0.5291017305947571 and parameters: {'high_window': 104, 'low_window': 62, 'atr_window': 12, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:40,711] Trial 75 finished with value: 0.2830509981867791 and parameters: {'high_window': 109, 'low_window': 51, 'atr_window': 8, 'atr_multiple': 2}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:40,895] Trial 76 finished with value: 0.6101206183445516 and parameters: {'high_window': 129, 'low_window': 71, 'atr_window': 15, 'atr_multiple': 4}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:41,005] Trial 77 finished with value: 0.3102410244063669 and parameters: {'high_window': 83, 'low_window': 41, 'atr_window': 19, 'atr_multiple': 2}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:41,177] Trial 78 finished with value: 0.6095348519912362 and parameters: {'high_window': 116, 'low_window': 98, 'atr_window': 39, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:41,285] Trial 79 finished with value: 0.36697360418310276 and parameters: {'high_window': 89, 'low_window': 77, 'atr_window': 29, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:41,400] Trial 80 finished with value: 0.61604872760634 and parameters: {'high_window': 95, 'low_window': 85, 'atr_window': 34, 'atr_multiple': 5}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:41,517] Trial 81 finished with value: 0.5687358269511309 and parameters: {'high_window': 94, 'low_window': 87, 'atr_window': 34, 'atr_multiple': 5}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:41,631] Trial 82 finished with value: 0.6671478203431996 and parameters: {'high_window': 109, 'low_window': 104, 'atr_window': 31, 'atr_multiple': 4}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:41,762] Trial 83 finished with value: 0.6072990595167 and parameters: {'high_window': 147, 'low_window': 60, 'atr_window': 43, 'atr_multiple': 4}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:41,891] Trial 84 finished with value: 0.6427084665484892 and parameters: {'high_window': 106, 'low_window': 104, 'atr_window': 24, 'atr_multiple': 4}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:42,018] Trial 85 finished with value: 0.5858232016679336 and parameters: {'high_window': 108, 'low_window': 104, 'atr_window': 24, 'atr_multiple': 4}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:42,129] Trial 86 finished with value: 0.7822778541883372 and parameters: {'high_window': 105, 'low_window': 95, 'atr_window': 30, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:42,253] Trial 87 finished with value: 0.6072990595167 and parameters: {'high_window': 147, 'low_window': 94, 'atr_window': 29, 'atr_multiple': 4}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:42,379] Trial 88 finished with value: 0.6093999131995751 and parameters: {'high_window': 113, 'low_window': 107, 'atr_window': 31, 'atr_multiple': 4}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:42,563] Trial 89 finished with value: 0.6097149090957219 and parameters: {'high_window': 120, 'low_window': 97, 'atr_window': 27, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:42,670] Trial 90 finished with value: 0.563557109887873 and parameters: {'high_window': 74, 'low_window': 198, 'atr_window': 19, 'atr_multiple': 2}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:42,781] Trial 91 finished with value: 0.6689294411144262 and parameters: {'high_window': 101, 'low_window': 70, 'atr_window': 24, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:42,895] Trial 92 finished with value: 0.7482542471795548 and parameters: {'high_window': 103, 'low_window': 102, 'atr_window': 24, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:43,004] Trial 93 finished with value: 0.7206240272724763 and parameters: {'high_window': 83, 'low_window': 116, 'atr_window': 16, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:43,118] Trial 94 finished with value: 0.47215744156981293 and parameters: {'high_window': 57, 'low_window': 112, 'atr_window': 15, 'atr_multiple': 2}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:43,243] Trial 95 finished with value: 0.6745991887580666 and parameters: {'high_window': 68, 'low_window': 118, 'atr_window': 20, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:43,360] Trial 96 finished with value: -0.03977227056916818 and parameters: {'high_window': 80, 'low_window': 116, 'atr_window': 17, 'atr_multiple': 1}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:43,509] Trial 97 finished with value: 0.6096698799463565 and parameters: {'high_window': 64, 'low_window': 119, 'atr_window': 26, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:43,625] Trial 98 finished with value: 0.6755993097615641 and parameters: {'high_window': 69, 'low_window': 109, 'atr_window': 14, 'atr_multiple': 3}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:43,734] Trial 99 finished with value: 0.347173789461748 and parameters: {'high_window': 69, 'low_window': 108, 'atr_window': 5, 'atr_multiple': 2}. Best is trial 65 with value: 0.7851047779701882.
# [I 2023-07-11 15:05:43,848] Trial 100 finished with value: 0.8017229591151019 and parameters: {'high_window': 96, 'low_window': 115, 'atr_window': 14, 'atr_multiple': 3}. Best is trial 100 with value: 0.8017229591151019.
# [I 2023-07-11 15:05:43,977] Trial 101 finished with value: 0.7735371571163489 and parameters: {'high_window': 101, 'low_window': 100, 'atr_window': 13, 'atr_multiple': 3}. Best is trial 100 with value: 0.8017229591151019.
# [I 2023-07-11 15:05:44,100] Trial 102 finished with value: 0.676914453754802 and parameters: {'high_window': 86, 'low_window': 115, 'atr_window': 16, 'atr_multiple': 3}. Best is trial 100 with value: 0.8017229591151019.
# [I 2023-07-11 15:05:44,215] Trial 103 finished with value: 0.5853790172279147 and parameters: {'high_window': 84, 'low_window': 124, 'atr_window': 14, 'atr_multiple': 3}. Best is trial 100 with value: 0.8017229591151019.
# [I 2023-07-11 15:05:44,373] Trial 104 finished with value: 0.7336653178634531 and parameters: {'high_window': 96, 'low_window': 113, 'atr_window': 8, 'atr_multiple': 3}. Best is trial 100 with value: 0.8017229591151019.
# [I 2023-07-11 15:05:44,483] Trial 105 finished with value: 0.8261811145419343 and parameters: {'high_window': 96, 'low_window': 116, 'atr_window': 9, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:44,594] Trial 106 finished with value: 0.7336653178634531 and parameters: {'high_window': 96, 'low_window': 113, 'atr_window': 8, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:44,716] Trial 107 finished with value: 0.6843137368520491 and parameters: {'high_window': 96, 'low_window': 114, 'atr_window': 9, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:44,830] Trial 108 finished with value: 0.3838775442269201 and parameters: {'high_window': 94, 'low_window': 115, 'atr_window': 8, 'atr_multiple': 2}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:44,945] Trial 109 finished with value: 0.695359940002875 and parameters: {'high_window': 97, 'low_window': 123, 'atr_window': 9, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:45,083] Trial 110 finished with value: 0.6103463606002323 and parameters: {'high_window': 97, 'low_window': 134, 'atr_window': 7, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:45,212] Trial 111 finished with value: 0.6646597356281538 and parameters: {'high_window': 89, 'low_window': 122, 'atr_window': 9, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:45,332] Trial 112 finished with value: 0.7008751241442873 and parameters: {'high_window': 102, 'low_window': 113, 'atr_window': 12, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:45,461] Trial 113 finished with value: 0.8053388166106802 and parameters: {'high_window': 102, 'low_window': 121, 'atr_window': 12, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:45,573] Trial 114 finished with value: 0.30642108868743784 and parameters: {'high_window': 102, 'low_window': 123, 'atr_window': 13, 'atr_multiple': 2}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:45,703] Trial 115 finished with value: 0.6080884147502273 and parameters: {'high_window': 92, 'low_window': 139, 'atr_window': 6, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:45,912] Trial 116 finished with value: 0.6103011922187608 and parameters: {'high_window': 77, 'low_window': 133, 'atr_window': 12, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:46,087] Trial 117 finished with value: 0.461765771282611 and parameters: {'high_window': 113, 'low_window': 101, 'atr_window': 11, 'atr_multiple': 2}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:46,345] Trial 118 finished with value: 0.5199076517639433 and parameters: {'high_window': 103, 'low_window': 110, 'atr_window': 10, 'atr_multiple': 2}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:46,634] Trial 119 finished with value: 0.6695577276231915 and parameters: {'high_window': 99, 'low_window': 127, 'atr_window': 7, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:46,875] Trial 120 finished with value: 0.7444231040525667 and parameters: {'high_window': 83, 'low_window': 99, 'atr_window': 17, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:47,241] Trial 121 finished with value: 0.7413383882231454 and parameters: {'high_window': 82, 'low_window': 99, 'atr_window': 17, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:47,522] Trial 122 finished with value: 0.6864533134905221 and parameters: {'high_window': 84, 'low_window': 107, 'atr_window': 12, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:47,684] Trial 123 finished with value: 0.6788380674837718 and parameters: {'high_window': 88, 'low_window': 101, 'atr_window': 17, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:47,802] Trial 124 finished with value: 0.5994590823875415 and parameters: {'high_window': 81, 'low_window': 96, 'atr_window': 14, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:47,912] Trial 125 finished with value: 0.4061617021829556 and parameters: {'high_window': 200, 'low_window': 119, 'atr_window': 17, 'atr_multiple': 4}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:48,023] Trial 126 finished with value: 0.6374055633168784 and parameters: {'high_window': 90, 'low_window': 112, 'atr_window': 13, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:48,131] Trial 127 finished with value: 0.40102784340088127 and parameters: {'high_window': 103, 'low_window': 98, 'atr_window': 23, 'atr_multiple': 2}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:48,246] Trial 128 finished with value: 0.5282613250044129 and parameters: {'high_window': 112, 'low_window': 100, 'atr_window': 5, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:48,360] Trial 129 finished with value: 0.6604970452646635 and parameters: {'high_window': 117, 'low_window': 82, 'atr_window': 11, 'atr_multiple': 4}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:48,471] Trial 130 finished with value: 0.7525445298433251 and parameters: {'high_window': 78, 'low_window': 89, 'atr_window': 16, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:48,582] Trial 131 finished with value: 0.5066090352525521 and parameters: {'high_window': 78, 'low_window': 92, 'atr_window': 16, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:48,739] Trial 132 finished with value: 0.4863275137745044 and parameters: {'high_window': 93, 'low_window': 78, 'atr_window': 21, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:48,850] Trial 133 finished with value: 0.7070385794914682 and parameters: {'high_window': 100, 'low_window': 89, 'atr_window': 18, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:48,977] Trial 134 finished with value: 0.15294237367469396 and parameters: {'high_window': 85, 'low_window': 94, 'atr_window': 15, 'atr_multiple': 2}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:49,090] Trial 135 finished with value: 0.4223671296393301 and parameters: {'high_window': 90, 'low_window': 89, 'atr_window': 22, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:49,197] Trial 136 finished with value: 0.6687419910945439 and parameters: {'high_window': 98, 'low_window': 104, 'atr_window': 18, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:49,291] Trial 137 finished with value: 0.6229236706113739 and parameters: {'high_window': 104, 'low_window': 107, 'atr_window': 18, 'atr_multiple': 4}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:49,401] Trial 138 finished with value: 0.3537358292923767 and parameters: {'high_window': 75, 'low_window': 85, 'atr_window': 54, 'atr_multiple': 2}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:49,495] Trial 139 finished with value: 0.43031941802025586 and parameters: {'high_window': 107, 'low_window': 97, 'atr_window': 10, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:49,605] Trial 140 finished with value: 0.6302969248822445 and parameters: {'high_window': 121, 'low_window': 75, 'atr_window': 7, 'atr_multiple': 4}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:49,715] Trial 141 finished with value: 0.7106260275276028 and parameters: {'high_window': 100, 'low_window': 112, 'atr_window': 14, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:49,809] Trial 142 finished with value: 0.6648771603536769 and parameters: {'high_window': 94, 'low_window': 110, 'atr_window': 14, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:49,920] Trial 143 finished with value: 0.7448785721539285 and parameters: {'high_window': 98, 'low_window': 118, 'atr_window': 16, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:50,067] Trial 144 finished with value: 0.6915388802129846 and parameters: {'high_window': 111, 'low_window': 118, 'atr_window': 15, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:50,179] Trial 145 finished with value: 0.7232542753744174 and parameters: {'high_window': 83, 'low_window': 103, 'atr_window': 20, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:50,273] Trial 146 finished with value: 0.6712913376085241 and parameters: {'high_window': 86, 'low_window': 105, 'atr_window': 20, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:50,383] Trial 147 finished with value: 0.7453183302286259 and parameters: {'high_window': 72, 'low_window': 103, 'atr_window': 23, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:50,477] Trial 148 finished with value: 0.3989506102908592 and parameters: {'high_window': 72, 'low_window': 100, 'atr_window': 25, 'atr_multiple': 2}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:50,593] Trial 149 finished with value: 0.6570050224379177 and parameters: {'high_window': 79, 'low_window': 94, 'atr_window': 28, 'atr_multiple': 4}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:50,697] Trial 150 finished with value: 0.6814822513262381 and parameters: {'high_window': 92, 'low_window': 103, 'atr_window': 22, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:50,807] Trial 151 finished with value: 0.6207190453141309 and parameters: {'high_window': 83, 'low_window': 120, 'atr_window': 20, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:50,901] Trial 152 finished with value: 0.751218172021563 and parameters: {'high_window': 96, 'low_window': 115, 'atr_window': 16, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:51,011] Trial 153 finished with value: 0.7343244751727882 and parameters: {'high_window': 97, 'low_window': 107, 'atr_window': 12, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:51,124] Trial 154 finished with value: 0.49990718745919116 and parameters: {'high_window': 106, 'low_window': 108, 'atr_window': 9, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:51,250] Trial 155 finished with value: 0.6249436888228295 and parameters: {'high_window': 96, 'low_window': 127, 'atr_window': 12, 'atr_multiple': 3}. Best is trial 105 with value: 0.8261811145419343.
# [I 2023-07-11 15:05:51,395] Trial 156 finished with value: 0.8384709288839108 and parameters: {'high_window': 98, 'low_window': 116, 'atr_window': 10, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:51,501] Trial 157 finished with value: 0.8101698702925665 and parameters: {'high_window': 105, 'low_window': 116, 'atr_window': 11, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:51,611] Trial 158 finished with value: 0.34715298291452296 and parameters: {'high_window': 105, 'low_window': 122, 'atr_window': 17, 'atr_multiple': 2}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:51,705] Trial 159 finished with value: 0.7783970370311091 and parameters: {'high_window': 115, 'low_window': 97, 'atr_window': 11, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:51,815] Trial 160 finished with value: 0.658889329590704 and parameters: {'high_window': 115, 'low_window': 97, 'atr_window': 11, 'atr_multiple': 4}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:51,925] Trial 161 finished with value: 0.6840013987145634 and parameters: {'high_window': 120, 'low_window': 84, 'atr_window': 14, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:52,035] Trial 162 finished with value: 0.767527932889406 and parameters: {'high_window': 110, 'low_window': 108, 'atr_window': 12, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:52,130] Trial 163 finished with value: 0.6260884849253265 and parameters: {'high_window': 125, 'low_window': 117, 'atr_window': 10, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:52,240] Trial 164 finished with value: 0.7601749468031102 and parameters: {'high_window': 110, 'low_window': 100, 'atr_window': 16, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:52,350] Trial 165 finished with value: 0.7509019975729286 and parameters: {'high_window': 110, 'low_window': 92, 'atr_window': 13, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:52,485] Trial 166 finished with value: 0.6092201333407395 and parameters: {'high_window': 109, 'low_window': 91, 'atr_window': 36, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:52,579] Trial 167 finished with value: 0.7739453498189209 and parameters: {'high_window': 116, 'low_window': 110, 'atr_window': 13, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:52,689] Trial 168 finished with value: 0.7739453498189209 and parameters: {'high_window': 116, 'low_window': 94, 'atr_window': 13, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:52,846] Trial 169 finished with value: 0.6101206183445516 and parameters: {'high_window': 129, 'low_window': 94, 'atr_window': 13, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:52,956] Trial 170 finished with value: 0.6975649166975606 and parameters: {'high_window': 115, 'low_window': 90, 'atr_window': 6, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:53,067] Trial 171 finished with value: 0.7206049855744473 and parameters: {'high_window': 119, 'low_window': 109, 'atr_window': 10, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:53,161] Trial 172 finished with value: 0.7026732030313572 and parameters: {'high_window': 112, 'low_window': 15, 'atr_window': 13, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:53,271] Trial 173 finished with value: 0.6249046685219546 and parameters: {'high_window': 109, 'low_window': 103, 'atr_window': 11, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:53,381] Trial 174 finished with value: 0.7257129717341643 and parameters: {'high_window': 116, 'low_window': 81, 'atr_window': 8, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:53,506] Trial 175 finished with value: 0.6099852924711083 and parameters: {'high_window': 126, 'low_window': 88, 'atr_window': 15, 'atr_multiple': 2}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:53,601] Trial 176 finished with value: 0.630494782873611 and parameters: {'high_window': 105, 'low_window': 96, 'atr_window': 13, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:53,710] Trial 177 finished with value: 0.652209638336828 and parameters: {'high_window': 113, 'low_window': 110, 'atr_window': 10, 'atr_multiple': 4}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:53,820] Trial 178 finished with value: 0.663204598592038 and parameters: {'high_window': 110, 'low_window': 102, 'atr_window': 5, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:53,930] Trial 179 finished with value: 0.6661985370780679 and parameters: {'high_window': 103, 'low_window': 106, 'atr_window': 15, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:54,058] Trial 180 finished with value: 0.24197358494688473 and parameters: {'high_window': 124, 'low_window': 114, 'atr_window': 12, 'atr_multiple': 2}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:54,175] Trial 181 finished with value: 0.6326491256595141 and parameters: {'high_window': 101, 'low_window': 120, 'atr_window': 19, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:54,327] Trial 182 finished with value: 0.6408563715406945 and parameters: {'high_window': 107, 'low_window': 125, 'atr_window': 15, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:54,433] Trial 183 finished with value: 0.7258342223690578 and parameters: {'high_window': 113, 'low_window': 116, 'atr_window': 16, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:54,528] Trial 184 finished with value: 0.7913886268857195 and parameters: {'high_window': 117, 'low_window': 92, 'atr_window': 9, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:54,669] Trial 185 finished with value: 0.7322838893976324 and parameters: {'high_window': 118, 'low_window': 93, 'atr_window': 8, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:54,802] Trial 186 finished with value: 0.6103463606002323 and parameters: {'high_window': 134, 'low_window': 87, 'atr_window': 10, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:54,918] Trial 187 finished with value: 0.7289184213369286 and parameters: {'high_window': 117, 'low_window': 99, 'atr_window': 7, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:55,012] Trial 188 finished with value: 0.6650230400670679 and parameters: {'high_window': 110, 'low_window': 95, 'atr_window': 12, 'atr_multiple': 4}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:55,123] Trial 189 finished with value: 0.5777634751240271 and parameters: {'high_window': 123, 'low_window': 84, 'atr_window': 9, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:55,234] Trial 190 finished with value: 0.7418177371146 and parameters: {'high_window': 105, 'low_window': 91, 'atr_window': 31, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:55,359] Trial 191 finished with value: 0.650870453030649 and parameters: {'high_window': 101, 'low_window': 111, 'atr_window': 13, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:55,468] Trial 192 finished with value: 0.5914990271497959 and parameters: {'high_window': 99, 'low_window': 190, 'atr_window': 26, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:55,578] Trial 193 finished with value: 0.7066106737443566 and parameters: {'high_window': 107, 'low_window': 118, 'atr_window': 16, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:55,685] Trial 194 finished with value: 0.7297536192094618 and parameters: {'high_window': 112, 'low_window': 105, 'atr_window': 14, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:55,832] Trial 195 finished with value: 0.5580882967571292 and parameters: {'high_window': 104, 'low_window': 100, 'atr_window': 11, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:55,957] Trial 196 finished with value: 0.610165746872645 and parameters: {'high_window': 114, 'low_window': 130, 'atr_window': 59, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:56,072] Trial 197 finished with value: 0.7807205155029769 and parameters: {'high_window': 108, 'low_window': 114, 'atr_window': 18, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:56,182] Trial 198 finished with value: 0.6194418608301162 and parameters: {'high_window': 118, 'low_window': 108, 'atr_window': 21, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# [I 2023-07-11 15:05:56,282] Trial 199 finished with value: 0.6490812124595701 and parameters: {'high_window': 109, 'low_window': 114, 'atr_window': 23, 'atr_multiple': 3}. Best is trial 156 with value: 0.8384709288839108.
# Best Parameters: {'high_window': 98, 'low_window': 116, 'atr_window': 10, 'atr_multiple': 3}
# Best Value: 0.8384709288839108

# %% [markdown]
# ### Effects of High/Low Window

# %%
hl_period = np.arange(5, 201, 5)
results = []

for i in range(len(hl_period)):
    for j in range(len(hl_period)):
        # print(i, j)
        bt, _ = hatr_backtest(
            df.copy(), 
            high_window=hl_period[i], 
            low_window=hl_period[j], 
            atr_window=best_params['atr_window'], 
            atr_multiple=best_params['atr_multiple']
            )
        bt.analyse()
        results.append((hl_period[i], hl_period[j], bt.annual_return, bt.annual_vol, bt.sharpe))

# %%
print('Buy Hold Results')
print(f'Annual Return = {bt.buy_hold_annual_return}')
print(f'Annual Volatility = {bt.buy_hold_annual_vol}')
print(f'Sharpe Ratio = {bt.buy_hold_sharpe}')
print('-----------')
best_sr = max(results, key=lambda x: x[2])
print(f'Max Total Returns:')
print(f'High Window = {best_sr[0]}, Low Window = {best_sr[1]}')
print(f'Annual Return = {best_sr[2]}')
print(f'Annual Volatility = {best_sr[3]}')
print(f'Sharpe Ratio = {best_sr[4]}')
print('-----------')
best_sr = max(results, key=lambda x: x[4])
print(f'Max Sharpe Ratio:')
print(f'High Window = {best_sr[0]}, Low Window = {best_sr[1]}')
print(f'Annual Return = {best_sr[2]}')
print(f'Annual Volatility = {best_sr[3]}')
print(f'Sharpe Ratio = {best_sr[4]}')
print('-----------')
# Out:
# Buy Hold Results
# Annual Return = 0.14649373701308166
# Annual Volatility = 0.19060222599543294
# Sharpe Ratio = 0.7685835579726746
# -----------
# Max Total Returns:
# High Window = 5, Low Window = 125
# Annual Return = 0.11705779768646152
# Annual Volatility = 0.1901514944810544
# Sharpe Ratio = 0.6156028276607864
# -----------
# Max Sharpe Ratio:
# High Window = 40, Low Window = 115
# Annual Return = 0.08329145992378062
# Annual Volatility = 0.09037025078059294
# Sharpe Ratio = 0.9216690139103554
# -----------

# %%
x = np.array([f[0] for f in results])
y = np.array([f[1] for f in results])
z = np.array([f[2] for f in results])

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_trisurf(x, y, z, cmap='jet', linewidth=0)
fig.colorbar(surf)

# Set labels and title
ax.set_xlabel('High window')
ax.set_ylabel('Low window')
ax.set_zlabel('Annual Return')
ax.set_title('Annual Return')

fig.tight_layout()

plt.show()

# %%
x = np.array([f[0] for f in results])
y = np.array([f[1] for f in results])
z = np.array([f[3] for f in results])

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_trisurf(x, y, z, cmap='jet', linewidth=0)
fig.colorbar(surf)

# Set labels and title
ax.set_xlabel('High window')
ax.set_ylabel('Low window')
ax.set_zlabel('Annual Return')
ax.set_title('Annual Volatility')

fig.tight_layout()

plt.show()

# %%
x = np.array([f[0] for f in results])
y = np.array([f[1] for f in results])
z = np.array([f[4] for f in results])

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_trisurf(x, y, z, cmap='jet', linewidth=0)
fig.colorbar(surf)

# Set labels and title
ax.set_xlabel('High window')
ax.set_ylabel('Low window')
ax.set_zlabel('Annual Return')
ax.set_title('Sharpe Ratio')

fig.tight_layout()

plt.show()

# %% [markdown]
# ### Effects of ATR multiple and ATR window

# %%
atr_window_range = np.arange(5, 101, 5)
atr_multiple_range = np.arange(1, 11, 1)
results = []

for i in range(len(atr_window_range)):
    for j in range(len(atr_multiple_range)):
        # print(i, j)
        bt, _ = hatr_backtest(
            df.copy(), 
            high_window=best_params['high_window'], 
            low_window=best_params['low_window'], 
            atr_window=atr_window_range[i], 
            atr_multiple=atr_multiple_range[j]
            )
        bt.analyse()
        results.append((atr_window_range[i], atr_multiple_range[j], bt.annual_return, bt.annual_vol, bt.sharpe))

# %%
print('Buy Hold Results')
print(f'Annual Return = {bt.buy_hold_annual_return}')
print(f'Annual Volatility = {bt.buy_hold_annual_vol}')
print(f'Sharpe Ratio = {bt.buy_hold_sharpe}')
print('-----------')
best_sr = max(results, key=lambda x: x[2])
print(f'Max Total Returns:')
print(f'ATR Window = {best_sr[0]}, ATR multiple = {best_sr[1]}')
print(f'Annual Return = {best_sr[2]}')
print(f'Annual Volatility = {best_sr[3]}')
print(f'Sharpe Ratio = {best_sr[4]}')
print('-----------')
best_sr = max(results, key=lambda x: x[4])
print(f'Max Sharpe Ratio:')
print(f'ATR Window = {best_sr[0]}, ATR multiple = {best_sr[1]}')
print(f'Annual Return = {best_sr[2]}')
print(f'Annual Volatility = {best_sr[3]}')
print(f'Sharpe Ratio = {best_sr[4]}')
print('-----------')
# Out:
# Buy Hold Results
# Annual Return = 0.14733579772209593
# Annual Volatility = 0.1896893332022558
# Sharpe Ratio = 0.7767215754035018
# -----------
# Max Total Returns:
# ATR Window = 25, ATR multiple = 1
# Annual Return = 0.1158300098490459
# Annual Volatility = 0.1900301672179219
# Sharpe Ratio = 0.6095348519912362
# -----------
# Max Sharpe Ratio:
# ATR Window = 10, ATR multiple = 3
# Annual Return = 0.06493725410734119
# Annual Volatility = 0.0774472338519586
# Sharpe Ratio = 0.8384709288839108
# -----------

# %%
x = np.array([f[0] for f in results])
y = np.array([f[1] for f in results])
z = np.array([f[2] for f in results])

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_trisurf(x, y, z, cmap='jet', linewidth=0)
fig.colorbar(surf)

# Set labels and title
ax.set_xlabel('ATR window')
ax.set_ylabel('ATR multiple')
ax.set_zlabel('Annual Return')
ax.set_title('Annual Return')

fig.tight_layout()

plt.show()

# %%
x = np.array([f[0] for f in results])
y = np.array([f[1] for f in results])
z = np.array([f[3] for f in results])

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_trisurf(x, y, z, cmap='jet', linewidth=0)
fig.colorbar(surf)

# Set labels and title
ax.set_xlabel('ATR window')
ax.set_ylabel('ATR multiple')
ax.set_zlabel('Annual Return')
ax.set_title('Annual Volatility')

fig.tight_layout()

plt.show()

# %%
x = np.array([f[0] for f in results])
y = np.array([f[1] for f in results])
z = np.array([f[4] for f in results])

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_trisurf(x, y, z, cmap='jet', linewidth=0)
fig.colorbar(surf)

# Set labels and title
ax.set_xlabel('ATR window')
ax.set_ylabel('ATR multiple')
ax.set_zlabel('Annual Return')
ax.set_title('Sharpe Ratio')

fig.tight_layout()

plt.show()

# %% [markdown]
# ### Portfolio Stats
#
# This section looks at the stats of a portfolio that runs this trade at no leverage.
#
# This portfolio has lower returns and lower volatility/drawdowns compared to a buy-hold strategy. The portfolio manages to avoid the large drawdown events, thus preserving capital.

# %%
bt, tl = hatr_backtest(
    df.copy(), 
    high_window=best_params['high_window'], 
    low_window=best_params['low_window'], 
    atr_window=best_params['atr_window'], 
    atr_multiple=best_params['atr_multiple'])

bt.analyse()
bt.plot_graphs()

# %%
fig, ax1 = plt.subplots()

color = 'C0'
ax1.set_xlabel('time')
ax1.set_ylabel('returns', color=color)
ax1.plot(bt.date, bt.records['cum_returns'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

color = 'C1'
ax2 = ax1.twinx()
ax2.set_ylabel('returns', color=color)
ax2.plot(bt.date, bt.records['buy_hold_cum_returns'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax1.set_facecolor('xkcd:white')
plt.show()

# %%
print(f'Annualised return:          {bt.annual_return}')
print(f'buy_hold annual return:     {bt.buy_hold_annual_return}')
print('---------')
print(f'Annualised vol:             {bt.annual_vol}')
print(f'buy_hold annual vol:        {bt.buy_hold_annual_vol}')
print('---------')
print(f'Sharpe ratio:               {bt.sharpe}')
print(f'buy_hold Sharpe ratio:      {bt.buy_hold_sharpe}')
# Out:
# Annualised return:          0.06493725410734119
# buy_hold annual return:     0.14733579772209593
# ---------
# Annualised vol:             0.0774472338519586
# buy_hold annual vol:        0.1896893332022558
# ---------
# Sharpe ratio:               0.8384709288839108
# buy_hold Sharpe ratio:      0.7767215754035018

# %% [markdown]
# ### Trade record stats
#
# This section looks at the backtest results on a trade-by-trade basis.

# %%
tl.analyse(bt.df)
tl.stats
# Out:
# {'num_wins': 36,
#  'num_loss': 36,
#  'win_rate': 0.5,
#  'profit_total': 2501007.354268645,
#  'profit_mean': 34736.21325373118,
#  'returns_mean': 0.01915684254944916,
#  'returns_std': 0.05979414787866912,
#  'time_in_trade_mean': 60.47222222222222,
#  'time_in_trade_std': 102.6410362190432,
#  'capital_at_risk_mean': 1627019.9934011037,
#  'win_returns_mean': 0.055059505567989435,
#  'win_returns_std': 0.0660983389900877,
#  'win_profit_mean': 97055.929523023,
#  'win_time_in_trade_mean': 101.55555555555556,
#  'win_time_in_trade_std': 132.85468849072754,
#  'loss_returns_mean': -0.016745820469091118,
#  'loss_returns_std': 0.015237544518272344,
#  'loss_profit_mean': -27583.503015560636,
#  'loss_time_in_trade_mean': 19.38888888888889,
#  'loss_time_in_trade_std': 15.77570967890243}

# %% [markdown]
# We plot every single trade to view the characteristics of each trade.

# %%
tl.plot_all_trades()
# Out:
# trade 0
# entry: [45.8125]
# cost_basis: 45.8125
# exit: 45.553125
# returns: -0.005661664392905835
# trade 1
# entry: [47.03125]
# cost_basis: 47.03125
# exit: 45.784375
# returns: -0.026511627906976806
# trade 2
# entry: [47.5625]
# cost_basis: 47.5625
# exit: 47.515625
# returns: -0.0009855453350854138
# trade 3
# entry: [46.453125]
# cost_basis: 46.453125
# exit: 46.596875
# returns: 0.0030945173225697337
# trade 4
# entry: [48.015625]
# cost_basis: 48.015625
# exit: 48.3171875
# returns: 0.006280507647250304
# trade 5
# entry: [49.234375]
# cost_basis: 49.234375
# exit: 55.04375
# returns: 0.11799428752776903
# trade 6
# entry: [56.453125]
# cost_basis: 56.453125
# exit: 55.8078125
# returns: -0.011430943814005032
# trade 7
# entry: [57.234375]
# cost_basis: 57.234375
# exit: 57.715625
# returns: 0.008408408408408457
# trade 8
# entry: [58.484375]
# cost_basis: 58.484375
# exit: 57.66875
# returns: -0.013946032594175746
# trade 9
# entry: [58.875]
# cost_basis: 58.875
# exit: 58.0296875
# returns: -0.014357749469214413
# trade 10
# entry: [59.21875]
# cost_basis: 59.21875
# exit: 61.64375
# returns: 0.04094986807387858
# trade 11
# entry: [63.0]
# cost_basis: 63.0
# exit: 65.2953125
# returns: 0.03643353174603166
# trade 12
# entry: [66.78125]
# cost_basis: 66.78125
# exit: 67.2234375
# returns: 0.006621431913898031
# trade 13
# entry: [66.1875]
# cost_basis: 66.1875
# exit: 66.184375
# returns: -4.721435316331872e-05
# trade 14
# entry: [68.65625]
# cost_basis: 68.65625
# exit: 74.38125
# returns: 0.08338643604915785
# trade 15
# entry: [76.71875]
# cost_basis: 76.71875
# exit: 76.74375
# returns: 0.00032586558044813926
# trade 16
# entry: [80.8125]
# cost_basis: 80.8125
# exit: 80.6640625
# returns: -0.0018368136117556072
# trade 17
# entry: [82.96875]
# cost_basis: 82.96875
# exit: 83.4296875
# returns: 0.005555555555555556
# trade 18
# entry: [85.34375]
# cost_basis: 85.34375
# exit: 92.9640625
# returns: 0.08928963749542289
# trade 19
# entry: [97.3125]
# cost_basis: 97.3125
# exit: 94.7734375
# returns: -0.02609184328837508
# trade 20
# entry: [98.5]
# cost_basis: 98.5
# exit: 95.896875
# returns: -0.026427664974619347
# trade 21
# entry: [98.78125]
# cost_basis: 98.78125
# exit: 108.39375
# returns: 0.09731097753875353
# trade 22
# entry: [113.90625]
# cost_basis: 113.90625
# exit: 114.921875
# returns: 0.008916323731138546
# trade 23
# entry: [119.0]
# cost_basis: 119.0
# exit: 114.8890625
# returns: -0.03454569327731097
# trade 24
# entry: [120.40625]
# cost_basis: 120.40625
# exit: 124.8203125
# returns: 0.03665974565273813
# trade 25
# entry: [127.078125]
# cost_basis: 127.078125
# exit: 128.7765625
# returns: 0.013365301856633559
# trade 26
# entry: [136.5]
# cost_basis: 136.5
# exit: 131.809375
# returns: -0.03436355311355319
# trade 27
# entry: [134.5625]
# cost_basis: 134.5625
# exit: 130.578125
# returns: -0.0296098467254993
# trade 28
# entry: [138.125]
# cost_basis: 138.125
# exit: 134.009375
# returns: -0.0297963800904977
# trade 29
# entry: [142.25]
# cost_basis: 142.25
# exit: 141.1671875
# returns: -0.007612038664323295
# trade 30
# entry: [149.5625]
# cost_basis: 149.5625
# exit: 147.828125
# returns: -0.011596322607605515
# trade 31
# entry: [153.25]
# cost_basis: 153.25
# exit: 141.175
# returns: -0.07879282218597056
# trade 32
# entry: [93.41999816894533]
# cost_basis: 93.41999816894533
# exit: 110.84699783325196
# returns: 0.18654463718561404
# trade 33
# entry: [114.77999877929688]
# cost_basis: 114.77999877929688
# exit: 116.80999984741213
# returns: 0.017686017509188284
# trade 34
# entry: [121.66000366210938]
# cost_basis: 121.66000366210938
# exit: 120.41800613403322
# returns: -0.010208757937617679
# trade 35
# entry: [122.79000091552734]
# cost_basis: 122.79000091552734
# exit: 121.50600051879881
# returns: -0.010456880748879953
# trade 36
# entry: [125.1500015258789]
# cost_basis: 125.1500015258789
# exit: 125.38100128173828
# returns: 0.0018457830846418753
# trade 37
# entry: [128.4199981689453]
# cost_basis: 128.4199981689453
# exit: 126.72500381469726
# returns: -0.01319883490434388
# trade 38
# entry: [129.27000427246094]
# cost_basis: 129.27000427246094
# exit: 128.74099884033203
# returns: -0.004092251989208054
# trade 39
# entry: [132.5]
# cost_basis: 132.5
# exit: 142.64000549316407
# returns: 0.07652834334463447
# trade 40
# entry: [146.97000122070312]
# cost_basis: 146.97000122070312
# exit: 150.0270034790039
# returns: 0.02080017849159643
# trade 41
# entry: [152.6999969482422]
# cost_basis: 152.6999969482422
# exit: 151.3189926147461
# returns: -0.009043905442671269
# trade 42
# entry: [154.57000732421875]
# cost_basis: 154.57000732421875
# exit: 152.35299072265624
# returns: -0.014343122834381423
# trade 43
# entry: [155.38999938964844]
# cost_basis: 155.38999938964844
# exit: 154.14800720214845
# returns: -0.007992742083649985
# trade 44
# entry: [94.4000015258789]
# cost_basis: 94.4000015258789
# exit: 109.49000778198246
# returns: 0.15985175860369835
# trade 45
# entry: [116.0199966430664]
# cost_basis: 116.0199966430664
# exit: 119.31099090576174
# returns: 0.028365750369912738
# trade 46
# entry: [122.62999725341795]
# cost_basis: 122.62999725341795
# exit: 128.77400665283204
# returns: 0.050102010413629376
# trade 47
# entry: [135.0500030517578]
# cost_basis: 135.0500030517578
# exit: 133.29799423217773
# returns: -0.01297303798585349
# trade 48
# entry: [128.72999572753906]
# cost_basis: 128.72999572753906
# exit: 137.53899993896485
# returns: 0.06843008237233465
# trade 49
# entry: [141.97999572753906]
# cost_basis: 141.97999572753906
# exit: 144.9179916381836
# returns: 0.020693027180269625
# trade 50
# entry: [147.97000122070312]
# cost_basis: 147.97000122070312
# exit: 154.34601898193358
# returns: 0.043089935180309784
# trade 51
# entry: [159.3300018310547]
# cost_basis: 159.3300018310547
# exit: 163.17200622558593
# returns: 0.024113502481504442
# trade 52
# entry: [168.52000427246094]
# cost_basis: 168.52000427246094
# exit: 167.9639862060547
# returns: -0.0032994187770567338
# trade 53
# entry: [170.4600067138672]
# cost_basis: 170.4600067138672
# exit: 169.39100189208983
# returns: -0.006271294026004458
# trade 54
# entry: [174.4499969482422]
# cost_basis: 174.4499969482422
# exit: 177.77200164794922
# returns: 0.019042732919580658
# trade 55
# entry: [182.4499969482422]
# cost_basis: 182.4499969482422
# exit: 179.49499969482423
# returns: -0.016196203358974228
# trade 56
# entry: [183.2700042724609]
# cost_basis: 183.2700042724609
# exit: 184.0280044555664
# returns: 0.004135975148331358
# trade 57
# entry: [189.1699981689453]
# cost_basis: 189.1699981689453
# exit: 183.74800720214844
# returns: -0.028662002533586528
# trade 58
# entry: [190.0399932861328]
# cost_basis: 190.0399932861328
# exit: 194.68300781249997
# returns: 0.024431775891385246
# trade 59
# entry: [199.08999633789065]
# cost_basis: 199.08999633789068
# exit: 196.9199966430664
# returns: -0.010899591816463744
# trade 60
# entry: [201.22999572753903]
# cost_basis: 201.22999572753903
# exit: 203.6970001220703
# returns: 0.012259625537494628
# trade 61
# entry: [206.42999267578125]
# cost_basis: 206.42999267578125
# exit: 205.46600341796872
# returns: -0.004669812004143066
# trade 62
# entry: [212.2400054931641]
# cost_basis: 212.24000549316412
# exit: 210.07799530029294
# returns: -0.01018662899036164
# trade 63
# entry: [210.25]
# cost_basis: 210.25
# exit: 202.28400115966795
# returns: -0.0378882227839812
# trade 64
# entry: [213.19000244140625]
# cost_basis: 213.19000244140625
# exit: 271.92701568603513
# returns: 0.2755148579763835
# trade 65
# entry: [280.5599975585937]
# cost_basis: 280.5599975585937
# exit: 286.9740020751953
# returns: 0.022861436314569654
# trade 66
# entry: [281.3699951171875]
# cost_basis: 281.3699951171875
# exit: 279.66300659179683
# returns: -0.006066704179597148
# trade 67
# entry: [286.0400085449219]
# cost_basis: 286.0400085449219
# exit: 283.6610382080078
# returns: -0.008316914647764876
# trade 68
# entry: [294.1300048828125]
# cost_basis: 294.1300048828125
# exit: 316.72699279785155
# returns: 0.07682653092139362
# trade 69
# entry: [326.45001220703125]
# cost_basis: 326.45001220703125
# exit: 346.8970062255859
# returns: 0.0626343797027871
# trade 70
# entry: [346.1300048828125]
# cost_basis: 346.1300048828125
# exit: 426.3599853515625
# returns: 0.2317914637187061
# trade 71
# entry: [414.8599853515625]
# cost_basis: 414.8599853515625
# exit: 400.5599884033203
# returns: -0.03446945343770391

# %% [markdown]
# We can plot the trades that occur over a specific period of time to see how this strategy perform.

# %%
start_datetime= pd.to_datetime(dt.date(2008, 1, 1))
end_datetime = pd.to_datetime(dt.date(2009, 1, 1))

tl.plot_time_period(df, start_datetime, end_datetime)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# We note that the time in trade for winning trades is generally higher than that of losing trades.

# %%
tl.win_records['time_in_trade'].hist(bins=20, label='wins')
tl.loss_records['time_in_trade'].hist(bins=20, label='losses')
plt.xlabel('time in trade (days)')
plt.ylabel('count')
plt.title('time in trade')
plt.legend()
plt.show()

# %%
plt.scatter(tl.win_records['time_in_trade'], tl.win_records['returns'], label='wins')
plt.scatter(tl.loss_records['time_in_trade'], tl.loss_records['returns'], label='losses')
plt.hlines(0, -10, 4000, color='red')
plt.legend()
plt.xlabel('time in trade (days)')
plt.ylabel('trade returns (%)')
plt.show()

# %% [markdown]
# ### Analysis
#
# We note that the turtle trading rules follow a trend-following or momentum trading strategy. The characteristic of these strategies is greater volatility, with lower win-rate but higher returns per winning trade.
#
# Ideally, the strategy goes long when a long-term upward trend is established and follows the trend until it is exhausted, while avoiding big drawdowns when long-term downward trends are established.
#
# The downside to this strategy is that short-term volatility is likely to cause whipsaw losses. An example of this is losses when the underlying is trading within a range.
#
# Therefore, the way to optimise this strategy is to pick the underlying to more frequent long-term trends with greater magnitude compared to short-term volatility. It does not matter which direction that long-term trend is in since we can just inverse the rules, e.g. go short when price breaks out under the 20-day low. This is also possibly why the original turtle traders focused on commodity trading, since commodities tend to exhibit trends based on the physical demand and supply of the commodity, whereas equities may be more volatile in the short-term due to speculation.
#
# Another key part to the success of this strategy is to trade diversified and uncorrelated assets so that the various assets will be trending at different times. This will go a long way towards reducing the volatility of a portfolio trading all of these assets.
#
# Another idea is to trade this strategy on leveraged ETFs, for example UPRO (3 x leveraged SP500) instead of trading on SPY. The nature of the ETF (3 x daily returns) is likely to cause the magnitude of long-term trends to increase significantly, thus increasing the returns per winning trade of this strategy. The volatility drag of the leverage should also reduce the number of whipsaw losing trades. Therefore, the overall profitability of this strategy on leveraged ETFs should increase. More testing is required however, since we have to account for a higher expense ratio, tracking error, and a lack of historical data since these ETFs are a relatively recent invention.
